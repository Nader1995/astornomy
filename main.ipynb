# %% [markdown]
# # Star Cluster Catalog Analysis with Pandas
#
# - PPMXL ----------------------------------> star/source ID
#
# - RAJ2000[deg] ---------------------------> Right Ascension in degrees
#
# - DEJ2000[deg] ---------------------------> Declination in degrees
#
# - pmRA[mas/yr] --------------------------> proper motion in RA
#
# - pmDE[mas/yr] --------------------------> proper motion in De
#
# - e_pmRA[mas/yr] -----------------------> error in proper motion RA
#
# - e_pmDE[mas/yr] -----------------------> error in proper motion Dec
#
# - Jmag[mag] -------------------------------> J-band infrared magnitude
#
# - e_Jmag[mag] ----------------------------> error in J magnitude
#
# - Kmag[mag] ------------------------------> K-band infrared magnitude
#
# - e_Kmag[mag] ---------------------------> error in K magnitude

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * The original .xlsx file is around 65 MB. Run the code below to read .csv file and get rid of all metadata and other unnecessary data in original .xlsx file:

# %%
df= pd.read_csv('vizier_votable_catalog.csv') # Enter /data/sample.csv if you want to use the sample dataset instead of the full one.

# %% [markdown]
# Just to take a grasp of dataset:

# %%
display(df.head())
# Out:
#                 PPMXL  RAJ2000[deg]  DEJ2000[deg]  pmRA[mas/yr]  pmDE[mas/yr]  \
# 0  407349000000000000     45.959256     49.962081          17.6           1.9
# 1  407352000000000000     45.959337     49.891708          -5.3           0.6
# 2  407349000000000000     45.959650     49.898794          -2.9           0.7
# 3  407350000000000000     45.959841     49.992809           0.4           2.9
# 4  407349000000000000     45.960393     49.909459          -4.9           4.0
#
#    e_pmRA[mas/yr]  e_pmDE[mas/yr] Jmag[mag] e_Jmag[mag] Kmag[mag]  e_Kmag[mag]
# 0             6.3             6.3    16.713       0.146    15.928          NaN
# 1             5.5             5.5                                          NaN
# 2             4.8             4.8    16.899       0.167      15.7        0.196
# 3             5.5             5.5                                          NaN
# 4             4.8             4.8      16.7       0.129    15.693        0.201

# %% [markdown]
# And to have more information about our dataset:

# %%
display(df.describe())
display(df.info())
# Out:
#               PPMXL   RAJ2000[deg]   DEJ2000[deg]   pmRA[mas/yr]  \
# count  9.363290e+05  936329.000000  936329.000000  936329.000000
# mean   4.385381e+17      51.163103      49.860171      -2.302923
# std    4.349696e+16       2.515901       1.641183      56.174083
# min    4.069950e+17      45.958814      46.561318   -8283.200000
# 25%    4.105920e+17      49.173383      48.526469      -5.000000
# 50%    4.127500e+17      51.139387      49.852997      -1.000000
# 75%    5.058270e+17      53.180827      51.211242       3.400000
# max    5.106180e+17      56.203615      53.160317    7784.300000
#
#         pmDE[mas/yr]  e_pmRA[mas/yr]  e_pmDE[mas/yr]    e_Kmag[mag]
# count  936329.000000   936329.000000   936329.000000  451341.000000
# mean       -3.426207        6.021949        6.023579       0.111040
# std        74.676329        2.503662        2.504908       0.075859
# min     -7681.700000        0.200000        0.200000       0.000000
# 25%        -7.300000        4.300000        4.300000       0.050000
# 50%        -2.500000        5.600000        5.600000       0.102000
# 75%         1.600000        7.200000        7.200000       0.163000
# max      8136.700000       50.000000       50.000000       9.998000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936329 entries, 0 to 936328
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PPMXL           936329 non-null  int64
#  1   RAJ2000[deg]    936329 non-null  float64
#  2   DEJ2000[deg]    936329 non-null  float64
#  3   pmRA[mas/yr]    936329 non-null  float64
#  4   pmDE[mas/yr]    936329 non-null  float64
#  5   e_pmRA[mas/yr]  936329 non-null  float64
#  6   e_pmDE[mas/yr]  936329 non-null  float64
#  7   Jmag[mag]       936329 non-null  object
#  8   e_Jmag[mag]     936329 non-null  object
#  9   Kmag[mag]       936329 non-null  object
#  10  e_Kmag[mag]     451341 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 78.6+ MB
# None

# %% [markdown]
# We have around 9 hundred thousand stars, in total 19 million information distributed in 11 columns :

# %%
display(df.size)
display(df.shape)
# Out:
# 10299619
# (936329, 11)

# %% [markdown]
# ## Drop NaN
# First of all, let's see how many NaN values we have among all elements and then drop them.
#     - first count the NaN

# %%
display(df.sample(10))
display(df.isnull().sum())
# Out:
#                      PPMXL  RAJ2000[deg]  DEJ2000[deg]  pmRA[mas/yr]  \
# 41016   510184000000000000     55.194870     49.936168          -2.0
# 417078  412489000000000000     51.022133     48.660895          -4.6
# 468068  509120000000000000     53.079438     51.241151          -3.8
# 451963  409654000000000000     49.534892     51.190553          11.5
# 777288  509516000000000000     54.024969     52.241249          -0.1
# 641920  509704000000000000     55.405686     51.521295          17.0
# 501840  413322000000000000     52.100587     48.257694          -0.9
# 224825  509456000000000000     55.250445     50.273837          -2.5
# 771493  506074000000000000     52.734786     52.220136           3.0
# 829291  506009000000000000     51.850012     52.368057           7.2
#
#         pmDE[mas/yr]  e_pmRA[mas/yr]  e_pmDE[mas/yr] Jmag[mag] e_Jmag[mag]  \
# 41016           -3.4             7.4             7.4
# 417078         -11.1             6.4             6.4    16.233       0.126
# 468068         -11.1             5.9             5.9
# 451963         -35.6             5.4             5.4    13.219       0.023
# 777288          -9.3             5.1             5.1    16.735       0.156
# 641920          -3.8             4.0             4.0     13.62       0.034
# 501840          -4.0             4.5             4.5    15.601        0.07
# 224825          -6.5             4.2             4.2    15.378       0.057
# 771493           1.0             6.2             6.2    16.326       0.106
# 829291         -11.5             5.5             5.5    15.734        0.09
#
#        Kmag[mag]  e_Kmag[mag]
# 41016                     NaN
# 417078    15.591          NaN
# 468068                    NaN
# 451963    12.358        0.023
# 777288    15.854        0.221
# 641920     12.75          NaN
# 501840    15.243        0.153
# 224825    14.904        0.135
# 771493    15.529        0.163
# 829291    14.839        0.118
# PPMXL                  0
# RAJ2000[deg]           0
# DEJ2000[deg]           0
# pmRA[mas/yr]           0
# pmDE[mas/yr]           0
# e_pmRA[mas/yr]         0
# e_pmDE[mas/yr]         0
# Jmag[mag]              0
# e_Jmag[mag]            0
# Kmag[mag]              0
# e_Kmag[mag]       484988
# dtype: int64

# %% [markdown]
# It seems there is only one column **e_Kmag[mag]** containing actually NaN, and the rest of them contain empty cells. Let's replace empty cells by NaN and the drop them:

# %%
df = df.replace(
 
    r'^\s*$',
    np.nan,
    regex=True
)

# %%
display(df.sample(10, random_state=53))
display(df.isnull().sum())
# Out:
#                      PPMXL  RAJ2000[deg]  DEJ2000[deg]  pmRA[mas/yr]  \
# 638622  509580000000000000     54.557817     51.613627          -7.1
# 140283  407390000000000000     46.561895     49.287592          17.9
# 100879  409085000000000000     48.172238     50.135233           5.9
# 473751  509754000000000000     54.667395     51.096806         -55.4
# 712472  509683000000000000     54.894513     51.911001          34.3
# 865557  413722000000000000     53.935258     47.232658           1.9
# 222993  509416000000000000     54.827487     50.386294          -5.0
# 930302  412028000000000000     52.219179     46.674993           3.3
# 932967  505782000000000000     50.868438     53.074816          -3.9
# 62283   412216000000000000     49.879609     49.531914          -2.8
#
#         pmDE[mas/yr]  e_pmRA[mas/yr]  e_pmDE[mas/yr] Jmag[mag] e_Jmag[mag]  \
# 638622          -8.8             6.6             6.6    16.944       0.215
# 140283         -73.6             9.0             9.0       NaN         NaN
# 100879          -0.1             4.8             4.8    15.932       0.075
# 473751          30.4             9.3             9.3       NaN         NaN
# 712472          16.1             5.4             5.4    15.117       0.046
# 865557           5.4             9.3             9.3       NaN         NaN
# 222993          -7.7             5.0             5.0    16.573        0.13
# 930302         -11.0             5.7             5.7       NaN         NaN
# 932967          -1.2             5.1             5.1    16.373       0.129
# 62283           -4.7             4.2             4.2    14.874       0.039
#
#        Kmag[mag]  e_Kmag[mag]
# 638622    15.785          NaN
# 140283       NaN          NaN
# 100879    15.606        0.191
# 473751       NaN          NaN
# 712472    14.267        0.067
# 865557       NaN          NaN
# 222993    15.717          NaN
# 930302       NaN          NaN
# 932967    15.742          NaN
# 62283     14.401        0.071
# PPMXL                  0
# RAJ2000[deg]           0
# DEJ2000[deg]           0
# pmRA[mas/yr]           0
# pmDE[mas/yr]           0
# e_pmRA[mas/yr]         0
# e_pmDE[mas/yr]         0
# Jmag[mag]         419424
# e_Jmag[mag]       423781
# Kmag[mag]         419424
# e_Kmag[mag]       484988
# dtype: int64

# %% [markdown]
# Second, we drop all rows containing NaN:

# %%
display(f"Number of rows before dropping null values: {len(df)}")
df_cleaned = df.dropna()
display(f"Number of rows after dropping null values: {len(df_cleaned)}")
# Out:
# 'Number of rows before dropping null values: 936329'
# 'Number of rows after dropping null values: 448891'

# %% [markdown]
# Now we find the rows for which Jmag > 15.5, display their total number and then drop them:
# But before we get into that, let's check if any element of column Jmag is anything other than number. To do that, we convert all column to number. If it is already a number, it won't change, otherwise, if it is a string or anything else, it will change to NaN:

# %%
df_cleaned.loc[:, 'Jmag[mag]'] = pd.to_numeric(df_cleaned['Jmag[mag]'], errors='coerce')

display(df_cleaned['Jmag[mag]'].isna().sum())
# Out:
# 0

# %% [markdown]
# The code above assures us that all element of column **Jmag** is a valid number, so:

# %%
df_cleaned_Jmag_deleted = df_cleaned[df_cleaned['Jmag[mag]'] > 15.5]
display(f"Number of rows to be deleted based on Jmag[mag] > 15.5: {len(df_cleaned_Jmag_deleted)}")

df_cleaned_Jmag = df_cleaned[df_cleaned['Jmag[mag]'] <= 15.5]   
display(f"Number of rows after filtering Jmag[mag] <= 15.5: {len(df_cleaned_Jmag)}")

display(f'Is it equal to the initial number of rows? {len(df_cleaned_Jmag) + len(df_cleaned_Jmag_deleted)==len(df_cleaned)}')
# Out:
# 'Number of rows to be deleted based on Jmag[mag] > 15.5: 234577'
# 'Number of rows after filtering Jmag[mag] <= 15.5: 214314'
# 'Is it equal to the initial number of rows? True'

# %% [markdown]
# Next we filter our dataset based on Kmag <= 15.4:

# %%
df_cleaned_Jmag.loc[:, 'Kmag[mag]'] = pd.to_numeric(df_cleaned_Jmag['Kmag[mag]'], errors='coerce')

df_cleaned_Kmag_deleted = df_cleaned_Jmag[df_cleaned_Jmag['Kmag[mag]'] > 15.4]
display(f"Number of rows to be deleted based on Kmag[mag] > 15.4: {len(df_cleaned_Kmag_deleted)}")

df_cleaned_Kmag = df_cleaned_Jmag[df_cleaned_Jmag['Kmag[mag]'] <= 15.4]   
display(f"Number of rows after filtering Kmag[mag] <= 15.4: {len(df_cleaned_Kmag)}")

display(f'Is it equal to the initial number of rows? {len(df_cleaned_Kmag) + len(df_cleaned_Kmag_deleted)==len(df_cleaned_Jmag)}')
# Out:
# 'Number of rows to be deleted based on Kmag[mag] > 15.4: 27'
# 'Number of rows after filtering Kmag[mag] <= 15.4: 214287'
# 'Is it equal to the initial number of rows? True'

# %% [markdown]
# Now we demand the error in proper motion (in Radian, e_pmRA) to be restricted between 4 and 10:

# %%
df_cleaned_Kmag.loc[:, 'e_pmRA[mas/yr]'] = pd.to_numeric(df_cleaned_Kmag['e_pmRA[mas/yr]'], errors='coerce')

df_cleaned_e_pmRA_deleted = df_cleaned_Kmag[(df_cleaned_Kmag['e_pmRA[mas/yr]'] > 10) | (df_cleaned_Kmag['e_pmRA[mas/yr]'] < 4)]
display(f"Number of rows to be deleted based on e_pmRA[mas/yr] > 10 or e_pmRA[mas/yr] < 4: {len(df_cleaned_e_pmRA_deleted)}")

df_cleaned_e_pmRA = df_cleaned_Kmag[(df_cleaned_Kmag['e_pmRA[mas/yr]'] <= 10) & (df_cleaned_Kmag['e_pmRA[mas/yr]'] >= 4)]
display(f"Number of rows after filtering e_pmRA[mas/yr] <= 10 and e_pmRA[mas/yr] >= 4: {len(df_cleaned_e_pmRA)}")

display(f'Is it equal to the initial number of rows? {len(df_cleaned_e_pmRA) + len(df_cleaned_e_pmRA_deleted)==len(df_cleaned_Kmag)}')
# Out:
# 'Number of rows to be deleted based on e_pmRA[mas/yr] > 10 or e_pmRA[mas/yr] < 4: 13035'
# 'Number of rows after filtering e_pmRA[mas/yr] <= 10 and e_pmRA[mas/yr] >= 4: 201252'
# 'Is it equal to the initial number of rows? True'

# %% [markdown]
# Now this time, we demand the error in proper motion (in Degree, e_pmDE) to be restricted between 4 and 10:

# %%
df_cleaned_e_pmRA.loc[:, 'e_pmDE[mas/yr]'] = pd.to_numeric(df_cleaned_e_pmRA['e_pmDE[mas/yr]'], errors='coerce')

df_processed_data_deleted = df_cleaned_e_pmRA[(df_cleaned_e_pmRA['e_pmDE[mas/yr]'] > 10) | (df_cleaned_e_pmRA['e_pmDE[mas/yr]'] < 4)]
display(f"Number of rows to be deleted based on e_pmDE[mas/yr] > 10 or e_pmDE[mas/yr] < 4: {len(df_processed_data_deleted)}")

df_processed_data = df_cleaned_e_pmRA[(df_cleaned_e_pmRA['e_pmDE[mas/yr]'] <= 10) & (df_cleaned_e_pmRA['e_pmDE[mas/yr]'] >= 4)]
display(f"Number of rows after filtering e_pmDE[mas/yr] <= 10 and e_pmDE[mas/yr] >= 4: {len(df_processed_data)}")

display(f'Is it equal to the initial number of rows? {len(df_processed_data) + len(df_processed_data_deleted)==len(df_cleaned_e_pmRA)}')
# Out:
# 'Number of rows to be deleted based on e_pmDE[mas/yr] > 10 or e_pmDE[mas/yr] < 4: 57'
# 'Number of rows after filtering e_pmDE[mas/yr] <= 10 and e_pmDE[mas/yr] >= 4: 201195'
# 'Is it equal to the initial number of rows? True'

# %% [markdown]
# Now we add another column, χ-squared (chi-squared), based on the correct columns:

# %%
RA_c = 52.5
Dec_c = 49.0
d_c = 172.4

mu_ac = 22.73
mu_dc = -26.51
e_ac = 0.17
e_dc = 0.17

s_ac0 = 0.7
s_dc0 = 0.7

s_ac1 = s_ac0/(d_c*4.74*10**(-3))
s_dc1 = s_dc0/(d_c*4.74*10**(-3))

df_processed_data.loc[:,'Chi_squared'] = (
        ((df_processed_data['pmRA[mas/yr]'] - mu_ac) ** 2) /
        ((df_processed_data['e_pmRA[mas/yr]'] ** 2) + e_ac ** 2 + s_ac1 ** 2) +
        ((df_processed_data['pmDE[mas/yr]'] - mu_dc) ** 2) /
        ((df_processed_data['e_pmDE[mas/yr]'] ** 2) + e_dc ** 2 + s_dc1 ** 2)
)

# %%
display(df_processed_data.sample(10))
# Out:
#                      PPMXL  RAJ2000[deg]  DEJ2000[deg]  pmRA[mas/yr]  \
# 895106  411413000000000000     50.294373     46.811403          -3.4
# 55917   410648000000000000     48.714494     49.519459          16.8
# 762436  505838000000000000     50.642071     52.006261           0.8
# 93931   407363000000000000     46.252256     50.026539          -7.5
# 705251  509096000000000000     53.142123     51.792812          -1.7
# 701045  506041000000000000     52.058198     51.793422           0.8
# 644578  410269000000000000     47.629266     47.906230           6.4
# 933011  505780000000000000     50.885057     53.142093          -2.1
# 117129  412960000000000000     51.535059     50.023378           0.2
# 757791  409542000000000000     49.606804     52.163851           3.3
#
#         pmDE[mas/yr]  e_pmRA[mas/yr]  e_pmDE[mas/yr] Jmag[mag] e_Jmag[mag]  \
# 895106          -1.9             4.0             4.0    14.445       0.033
# 55917           -3.2             4.0             4.0    14.718       0.037
# 762436          -5.2             4.2             4.2     15.13       0.044
# 93931           -1.9             4.0             4.0    14.611       0.023
# 705251          -1.7             4.0             4.0    12.964       0.024
# 701045          -0.9             4.1             4.1    14.824       0.046
# 644578          -2.5             4.0             4.0    14.988       0.044
# 933011          -0.8             4.2             4.2    15.161       0.041
# 117129          -6.8             4.3             4.3    15.292       0.052
# 757791           2.3             4.1             4.1    14.242        0.03
#
#        Kmag[mag]  e_Kmag[mag]  Chi_squared
# 895106    13.626        0.043    76.862956
# 55917     14.022        0.051    34.512444
# 762436    14.363        0.074    50.810050
# 93931     13.874        0.042    90.648104
# 705251    12.544        0.024    72.325017
# 701045    14.239        0.067    64.691163
# 644578    14.025        0.052    50.299182
# 933011    14.403        0.072    69.421036
# 117129    14.838        0.118    46.543394
# 757791    13.775        0.044    68.716958
